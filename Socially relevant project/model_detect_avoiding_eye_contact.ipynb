# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class EyeContactClassifier(nn.Module):
    def __init__(self):
        super(EyeContactClassifier, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(64 * 56 * 56, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, 2)  # 2 classes: avoiding eye contact or not
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.fc_layers(x)
        return x

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
train_dataset = datasets.ImageFolder(root='path_to_training_data', transform=transform) #here i have to give in a dataset
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
model = EyeContactClassifier()


criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 10

for epoch in range(num_epochs):
    for batch_idx, (data, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ddda7e253d4a> in <cell line: 3>()
#       2
#       3 for epoch in range(num_epochs):
# ----> 4     for batch_idx, (data, labels) in enumerate(train_loader):
#       5         optimizer.zero_grad()
#       6         outputs = model(data)
#
# NameError: name 'train_loader' is not defined

# %%
torch.save(model.state_dict(), 'avoiding_eye_contact.pth')
